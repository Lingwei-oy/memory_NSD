# %%
from cloudpathlib import S3Path, S3Client
from pathlib import Path
from utilities import ls, crawl

# Set up our cache path:
cache_path = Path('/home/jovyan/cache')
if not cache_path.exists():
    cache_path.mkdir()

# Create the root S3Path for the NSD:
nsd_base_path = S3Path(
    's3://natural-scenes-dataset/',
    client=S3Client(
        no_sign_request=True,
        local_cache_dir=cache_path))

# %%
import nibabel as nib

ls(nsd_base_path / 'nsddata_betas' / 'ppdata' / 'subj01' / 'func1mm' / 'betas_fithrf_GLMdenoise_RR')
# Out:
# [S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session01.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session02.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session03.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session04.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session05.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session06.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session07.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session08.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session09.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session10.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session11.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session12.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session13.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session14.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session15.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session16.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session17.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session18.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session19.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session20.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session21.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session22.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session23.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session24.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session25.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session26.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session27.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session28.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session29.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session30.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session31.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session32.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session33.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session34.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session35.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session36.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session37.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session38.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session39.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/FRACvalue_session40.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session01.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session02.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session03.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session04.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session05.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session06.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session07.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session08.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session09.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session10.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session11.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session12.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session13.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session14.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session15.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session16.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session17.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session18.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session19.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session20.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session21.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session22.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session23.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session24.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session25.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session26.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session27.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session28.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session29.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session30.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session31.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session32.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session33.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session34.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session35.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session36.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session37.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session38.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session39.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindex_session40.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session01.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session02.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session03.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session04.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session05.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session06.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session07.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session08.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session09.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session10.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session11.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session12.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session13.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session14.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session15.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session16.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session17.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session18.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session19.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session20.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session21.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session22.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session23.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session24.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session25.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session26.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session27.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session28.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session29.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session30.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session31.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session32.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session33.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session34.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session35.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session36.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session37.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session38.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session39.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/HRFindexrun_session40.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session01.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session02.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session03.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session04.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session05.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session06.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session07.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session08.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session09.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session10.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session11.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session12.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session13.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session14.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session15.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session16.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session17.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session18.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session19.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session20.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session21.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session22.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session23.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session24.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session25.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session26.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session27.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session28.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session29.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session30.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session31.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session32.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session33.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session34.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session35.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session36.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session37.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session38.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session39.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2_session40.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session01.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session02.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session03.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session04.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session05.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session06.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session07.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session08.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session09.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session10.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session11.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session12.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session13.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session14.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session15.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session16.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session17.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session18.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session19.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session20.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session21.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session22.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session23.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session24.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session25.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session26.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session27.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session28.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session29.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session30.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session31.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session32.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session33.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session34.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session35.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session36.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session37.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session38.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session39.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/R2run_session40.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session01.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session01.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session02.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session02.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session03.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session03.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session04.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session04.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session05.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session05.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session06.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session06.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session07.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session07.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session08.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session08.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session09.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session09.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session10.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session10.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session11.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session11.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session12.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session12.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session13.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session13.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session14.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session14.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session15.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session15.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session16.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session16.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session17.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session17.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session18.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session18.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session19.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session19.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session20.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session20.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session21.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session21.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session22.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session22.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session23.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session23.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session24.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session24.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session25.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session25.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session26.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session26.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session27.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session27.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session28.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session28.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session29.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session29.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session30.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session30.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session31.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session31.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session32.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session32.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session33.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session33.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session34.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session34.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session35.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session35.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session36.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session36.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session37.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session37.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session38.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session38.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session39.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session39.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session40.hdf5'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session40.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session01.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session02.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session03.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session04.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session05.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session06.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session07.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session08.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session09.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session10.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session11.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session12.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session13.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session14.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session15.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session16.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session17.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session18.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session19.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session20.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session21.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session22.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session23.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session24.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session25.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session26.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session27.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session28.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session29.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session30.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session31.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session32.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session33.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session34.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session35.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session36.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session37.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session38.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session39.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/meanbeta_session40.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/ncsnr.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/ncsnr_split1.nii.gz'),
#  S3Path('s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/ncsnr_split2.nii.gz')]

# %%
def load_beta_session(subject_id='subj01', resolution='func1mm', session_num=5):
    nsd_base_path = CloudPath(
        's3://natural-scenes-dataset/',
        S3Client(no_sign_request=True)
    )
    filename = f'betas_session{session_num:02d}.nii.gz'  # zero-padded
    file_path = nsd_base_path / 'nsddata_betas' / 'ppdata' / subject_id / resolution / 'betas_fithrf_GLMdenoise_RR' / filename
    print(f"Loading {file_path}")
    img = nib.load(file_path.fspath)
    print(f"Loaded image shape: {img.shape}")
    return img
# Example: load session 5 betas
img_session5 = load_beta_session(session_num=5)
# Out:
# Loading s3://natural-scenes-dataset/nsddata_betas/ppdata/subj01/func1mm/betas_fithrf_GLMdenoise_RR/betas_session05.nii.gz
# Loaded image shape: (145, 186, 148, 750)

# %%
import numpy as np
# load in behavioral data

# find the shared images - should be 1000 images that are shared across all subjects 
# use 73k ID and loop through to find whether there are
stiminfo = nsd_base_path / 'nsddata' / 'experiments' / 'nsd' / 'nsd_stim_info_merged.csv'

with stiminfo.open('r') as f:
    stimdata = pd.read_csv(f)

stimdata

#filter out where shared ID = True
# Assuming masterordering is a NumPy array
temp = masterordering[:750*30]  # First 750*30 elements
shared515 = []  # Store indices that appear exactly 3 times
for q in range(1, 1001):  # Loop from 1 to 1000 inclusive
    if np.sum(temp == q) == 3:
        shared515.append(q)

# Convert to numpy array if needed
shared515 = np.array(shared515)

# filter out "CHANGEMIND" == NaN
# filter out MISSINGDATA == 1 (buttons failed to be recorded)


# determine which sessions the images appeared in (should be first, second, and third) 


# ISOLD is 0 (the image is novel) or 1 (the image is old)
# we want to add variable that says when the item was encoded (0), when it was first seen again- retrieved (1), 
# and when it was last seen again- retrieved (2) 
# variable is encoded v. retrieved
# encoded (0) is when ISOLD == 0
# retrieved (1 & 2) is when ISOLD == 1:
    # retrieved first (1) is when session # and trial # are less than
    # retrieved second (2) is when session # and trial # are greater than 

# use filtered data to create index that can be used to filter nifti files for ONLY the trials that we want
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       1 import numpy as np
#       2 # load in behavioral data
#       3
#       4 # find the shared images - should be 1000 images that are shared across all subjects
#       5 # use 73k ID and loop through to find whether there are
#       6 # Assuming masterordering is a NumPy array
# ----> 7 temp = masterordering[:750*30]  # First 750*30 elements
#       8 print (temp.shape)
#       9 #shared515 = []  # Store indices that appear exactly 3 times
#      10 #for q in range(1, 1001):  # Loop from 1 to 1000 inclusive
#      11 #    if np.sum(temp == q) == 3:
#    (...)
#      32
#      33 # use filtered data to create index that can be used to filter nifti files for ONLY the trials that we want
#
# NameError: name 'masterordering' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 stiminfo = nsd_base_path / 'nsddata' / 'experiments' / 'nsd' / 'nsd_stim_info_merged.csv'
#       3 with stiminfo.open('r') as f:
#       4     stimdata = pd.read_csv(f)
#
# NameError: name 'nsd_base_path' is not defined
